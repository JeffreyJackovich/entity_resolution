# %%
import pandas as pd

# %%
OUTPUT_PATH='~/Desktop/software_analysis_projects/entity_resolution/data/raw/2_processed_donors_similarity.csv'

# %%
df = pd.read_csv(OUTPUT_PATH)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  767 non-null    int64
#  1   left_side   767 non-null    object
#  2   right_side  767 non-null    object
#  3   similarity  767 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 24.1+ KB

# %%
# df[(df['similarity'] < 1.0) & (df['similarity'] > 0.90)].count()
# df[(df['similarity'] > 0.9)].count()

# df[df['similarity'] > 0.9].unique()
# df.groupby('similarity').similarity.count()
# Out:
# Unnamed: 0    683
# left_side     683
# right_side    683
# similarity    683
# dtype: int64

# %%
df[(df['similarity'] <  0.99)]
# Out:
#      Unnamed: 0                                          left_side  \
# 67           67                               2239 n. western inc.
# 70           70                               225 w. ontario corp.
# 71           71  225 w. ontario corp. dba magnum's steak and lo...
# 74           74                                2264 n clark street
# 75           75                                2264 n clark street
# ..          ...                                                ...
# 319         319                  23rd ward regular democratic org.
# 320         320                  23rd ward regular democratic org.
# 321         321                  23rd ward regular democratic org.
# 322         322                  23rd ward regular democratic org.
# 323         323                  23rd ward regular democratic org.
#
#                                             right_side  similarity
# 67                                2239 n. western inc.    1.000000
# ...

# %%
df.sort_values(by='similarity').head(70)
# Out:
#       Unnamed: 0                          left_side  \
# 1892        1892  27th ward republican organization
# 1893        1893  27th ward republican organization
# 1675        1675       27th ward reg republican org
# 1683        1683     27th ward reg. republican org.
# 276          276          23rd ward regular dem org
# ...          ...                                ...
# 1085        1085  25th ward democratic organization
# 1084        1084  25th ward democratic organization
# 1107        1107  25th ward democratic organization
# 1082        1082  25th ward democratic organization
# 1110        1110  25th ward democratic organization
#
#                                      right_side  similarity
# 1892             27th ward reg. republican org.    0.802706
# 1893               27th ward reg republican org    0.802706
# 1675          27th ward republican organization    0.802706
# 1683          27th ward republican organization    0.802706
# ...
